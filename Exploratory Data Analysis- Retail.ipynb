# %% [markdown]
# # GRIP - The Sparks Foundation

# %% [markdown]
# ## Data Science & Business Analytics Intern

# %% [markdown]
# ## Exploratory Data Analysis - Retail

# %% [markdown]
# ## Author: Varidhi Jain

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('Desktop/SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis of Continuous variables

# %%
#plotting histogram
df.hist(bins=50 ,figsize=(20,20))
plt.show()

# %% [markdown]
# # Univariate Analysis of Categorical variables

# %%
df['Category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Sub-Category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %% [markdown]
# ##### The top state wise dealings are:
#       1. California
#       2. New York
#       3. Texas

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Jupiter            1
# Iowa City          1
# Cheyenne           1
# Conway             1
# Orland Park        1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# ##### The top city wise dealings are:
#       1. New York
#       2. Los Angeles
#       3. Philadelphia

# %%
df['Region'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #####  Most of the dealings take place in western region and lowest in Southern region.

# %%
df['Ship Mode'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis of Continuous variables

# %%
numerical_df=df.select_dtypes(exclude=[object])

# %%
#correlation between continuous variables
corr= numerical_df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ##### Sales and profit are moderately correlated. Quantity and profit are less moderately correlated. Discount and profit are negatively correlated.

# %%
# Visualing the correlation matrix using heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis of Continuous-Categorical variables

# %%
#pairplot on the basis of Ship Mode
sns.pairplot(df,hue='Ship Mode')

# %%
#creating a piechart for ship mode wise sales, profit and discount

df_shipmode = df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
#pie chart on basis of ship mode
df_shipmode.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
#pairplot based on category
sns.pairplot(df, hue='Category')

# %%
#creating a piechart for category wise sales, profit and discount

df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()

# %%
df_category.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# #####  Technology has higher sales and profit. Highest discount is on furniture.

# %%
#creating pairplot based on sub category
sns.pairplot(df, hue='Sub-Category')

# %%
# subcategory wise sales, profit and discount analysis
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
#piechart for subcategory wise sales analysis
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 30)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Copiers have the highest sales, followed by machines.

# %%
#piechart for subcategory wise discount analysis
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Discount'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 30)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Highest discount is provided on binders and lowest on labels.

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']]
# Out:
#                     Sales      Profit
# Sub-Category
# Tables         648.794771  -55.565771
# Bookcases      503.859633  -15.230509
# Supplies       245.650200   -6.258418
# Fasteners       13.936774    4.375660
# Art             34.068834    8.200737
# Furnishings     95.825668   13.645918
# Labels          34.303055   15.236962
# Binders        133.560560   19.843574
# Paper           57.284092   24.856620
# Storage        264.590553   25.152277
# Envelopes       64.867724   27.418019
# Machines      1645.553313   29.432669
# Appliances     230.755710   38.922758
# Chairs         532.332420   43.095894
# Phones         371.211534   50.073938
# Accessories    215.974604   54.111788
# Copiers       2198.941618  817.909190

# %% [markdown]
# ##### Highest profit is earned on Copiers and the least on fasteners. The company suffers the highest loss on tables, followed by bookcases.

# %%
#pairplot based on state
sns.pairplot(df,hue='State')

# %%
#state wise sales, profit, discount
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
#sorting states on profit basis
df_state1=df_state.sort_values('Profit')
df_state1
# Out:
#                             Sales  Discount      Profit
# State
# Ohio                   166.861697  0.324947  -36.186304
# Colorado               176.418231  0.316484  -35.867351
# North Carolina         223.305880  0.283534  -30.083985
# Tennessee              167.551219  0.291257  -29.189583
# Pennsylvania           198.487077  0.328620  -26.507598
# Texas                  172.779742  0.370193  -26.121174
# Illinois               162.939230  0.390041  -25.625787
# Arizona                157.508933  0.303571  -15.303235
# Oregon                 140.573790  0.288710   -9.600569
# Florida                233.612815  0.299347   -8.875461
# New Mexico             129.284378  0.059459   31.273408
# North Dakota           131.415714  0.000000   32.878529
# South Dakota           109.630000  0.000000   32.902358
# Kansas                 121.429583  0.000000   34.851813
# California             228.729451  0.072764   38.171608
# Idaho                  208.689810  0.085714   39.367767
# ...

# %% [markdown]
# ##### The company earns highest profit from Vermont and the highest losses are from the state of Ohio.

# %%
#sorting states on sales basis
df_state2=df_state.sort_values('Sales')
df_state2
# Out:
#                             Sales  Discount      Profit
# State
# South Dakota           109.630000  0.000000   32.902358
# Kansas                 121.429583  0.000000   34.851813
# New Mexico             129.284378  0.059459   31.273408
# North Dakota           131.415714  0.000000   32.878529
# Oregon                 140.573790  0.288710   -9.600569
# Iowa                   152.658667  0.000000   39.460397
# Arizona                157.508933  0.303571  -15.303235
# Maine                  158.816250  0.000000   56.810775
# Illinois               162.939230  0.390041  -25.625787
# Connecticut            163.223866  0.007317   42.823071
# Ohio                   166.861697  0.324947  -36.186304
# Tennessee              167.551219  0.291257  -29.189583
# Texas                  172.779742  0.370193  -26.121174
# Colorado               176.418231  0.316484  -35.867351
# Arkansas               194.635500  0.000000   66.811452
# Nebraska               196.445526  0.000000   53.607742
# ...

# %% [markdown]
# ##### The highest sales made by the company is in Wyoming , followed by Vemont.

# %%
#sorting states on discount basis
df_state3=df_state.sort_values('Discount')
df_state3
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Nebraska               196.445526  0.000000   53.607742
# Wisconsin              291.951000  0.000000   76.380004
# Missouri               336.441667  0.000000   97.518341
# Mississippi            203.232830  0.000000   59.867475
# Minnesota              335.541011  0.000000  121.608847
# Maine                  158.816250  0.000000   56.810775
# North Dakota           131.415714  0.000000   32.878529
# Kentucky               263.250000  0.000000   80.573357
# Kansas                 121.429583  0.000000   34.851813
# Iowa                   152.658667  0.000000   39.460397
# Indiana                359.431946  0.000000  123.375411
# Louisiana              219.453095  0.000000   52.288150
# South Dakota           109.630000  0.000000   32.902358
# Arkansas               194.635500  0.000000   66.811452
# South Carolina         201.945476  0.000000   42.120395
# ...

# %%
# Pairplot Based on Region
sns.pairplot(df,hue='Region')

# %%
#regionwise sales, profit and discount
df_region = df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
#piechart for region wise sales, profit and discount
df_region.plot.pie(subplots=True, 
                   figsize=(18, 20), 
                   autopct='%1.1f%%',
                   labels = df_region.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# ##### The highest sales are made to South region. The company provides highest discount in Central region and earns the highest profit from Western region.

# %%
# Pairplot Based on Segment
sns.pairplot(df,hue='Segment')

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(18, 20),
                    startangle=90,    
                    labels = df_segment.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# ##### The highest sales are made to Home offices and this segment is most profitable too.
